# %% [markdown]
# # Week 5c: Flow based chatbots
#
# This is the third notebook for this week. Using your knowledge from the two previous notebooks you will be tasked with making flow-based chatbots.
#
# Flow-base chatbots are the simplest form you can make using code. They follow pre-defined conversation paths, which is something that you can create easily using **if statements** that you have just had some practice with in the last notebook.
#
# If you have ever interacted with a customer service chatbot, or a simple slack-bot or other social media bot, then there is a good chance that this was built as a flow-based chatbot.
#
# For this week you have to make three different flow based chatbots of increasing complexity.
#
# These exercises are designed for you to learn coding from scratch. I strongly advise that you **do not use ChatGPT or other AI assistant to help you with coding for these exercises**. The only effective way to learn how to code is by writing it yourself and learning how to fix it when things go wrong. If you use AI now, you will not be practicing any of these important skills that you will need later on as you go further into the course.

# %% [markdown]
# ## Task 1: How are you chatbot
#
# The first task is to make a simple chatbot that asks the user how they are and responds accordingly. The dialog and flow of conversation is given in the flow-chart:
#
# ![media/week-2/task-1-how-are-you-bot.png](media/week-2/task-1-how-are-you-bot.png)
#
# **Tasks**
# 1. Make a new Python file in VSCode called `how_are_you_bot.py`.
# 2. Open this file.
# 3. Copy and paste the following into the first line of code:
# ```
# response = input('Hi, how are you?\n')
# ```
# > **Note:** `\n` is the way we represent the new-line character in Python strings code. This allows us the computer to put a new line in the string when it gets printed out without actually starting a new line and confusing the computer.
# You should put `\n` at the end of all of the things your chatbot says in the `input()` function, so that the user can put there response on a new line.
# 4. Write the rest of the code using **if statements**, to follow precisely what is specified in the flow chat.
# 5. Once you have finished coding you need to test your chatbot. Can you recreate the following conversations:
#
# > Bot: Hi, how are you?
# >
# > User: good
# >
# > Bot: That's great!
#
# > Bot: Hi, how are you?
# >
# > User: bad
# >
# > Bot: Sorry to hear that!
#
# > Bot: Hi, how are you?
# >
# > User: ok
# >
# > Bot: I did not understand

# %% [markdown]
# ## Task 2: Magic 8-ball chatbot
#
# The second task is to make a magic 8-ball chatbot that prompts users to ask a question about the future and will give the user a fortune.
#
# #### Part 1
#
# First try and recreate the chatbot specified in the flow chart:
#
# ![media/week-5/task-2a-magic-8-ball-bot.png](media/week-2/task-2a-magic-8-ball-bot.png)
#
# To simulate the random selection of text you need to use some code that can generate random numbers for you. To do this you will need to use the `random` library that is built into Python.
#
# **Tasks:**
# 1. Make a new Python file in VSCode called `magic-8-ball.py`.
# 2. Open this file.
# 3. Copy and paste the following into the first line of code:
# ```
# import random
# ```
# 1. The next line of code should print out 'Hello, I am the magic 8-ball.'
# 2. You then need to use the `input()` function to ask the user a question and get their response.
# 3. You now need to use [the function random.randint(start, stop)](https://www.w3schools.com/python/ref_random_randint.asp) to generate a random Int between 1 and 6.
# 4. Use **if-else** statements to give a generated response for each generated number as specified in the flow chart.
# 5. Test your chatbot several times to see different responses from it.
# 6. Move onto part 2
#
# ##### Part 2
#
# Now you have a basic working magic-8 ball, you now want to make a chatbot that will keep answering questions until the user gets bored, see the flow chart for the improved magic 8-ball chatbot:
#
# ![media/week-5/task-2b-magic-8-ball-bot.png](media/week-2/task-2b-magic-8-ball-bot.png)
#
# To do this you will need to use a `while` loop in combination with a Boolean variable. The boolean should be `True` by default, and changed to `False` when the user does not want to answer any more questions.

# %% [markdown]
# ## Task 3
#
# The third task is to make a chatbot that takes orders in a coffee shop. This will both require you to use the `input()` function, as well as **if-statements**.
#
# The conversation flow is given in the following flow chart:
#
# ![media/week-5/task-3-coffee-shop-bot.png](media/week-2/task-3-coffee-shop-bot.png)
#
# Create a file called `week-10-coffee-shop-bot.py` and write your code into there. You will need to complete this by next week, as next weeks activity will be building upon the code you have written for this task.
#
# **Tip:** You will need to use the `quit()` to stop the chatbot when it does not know how to respond to the user input.
#
# To test your coffee shop bot, can you recreate the following conversations using your own name?
#
# > Bot: Welcome to the coffee shop, what drink would you like?
# >
# > User: americano
# >
# > Bot: Do you want milk with that?
# >
# > User: yes
# >
# > Bot: What size would you like?
# >
# > User:large
# >
# > Bot: Can I take a name for the order?
# >
# > User: Terry
# >
# > Bot: Thanks Terry, your large americano will be ready soon
#
# > Bot: Welcome to the coffee shop, what drink would you like?
# >
# > User: cappucino
# >
# > Bot: What size would you like?
# >
# > User:large
# >
# > Bot: Can I take a name for the order?
# >
# > User: Terry
# >
# > Bot: Thanks Terry, your large cappucino will be ready soon
#
# > Bot: Welcome to the coffee shop, what drink would you like?
# >
# > User: flat white
# >
# > Bot: I do not understand

# %% [markdown]
# ### Coffee shop bot bonus tasks
#
# If you have finished all the tasks and want to challenge youself further, can you:
# - Change the final piece of dialogue so that it tells the user if they have ordered a 'white' or 'black' americano, depending on whether they have chosen the option to have milk or not in the drink.
# - Use a while loop to repeat a question if the user does not select one of the pre-defined options for either:
#   - the drink
#   - the size
#   - milk option
# - Can you add any other drinks to the menu which only have a single size, such as a `flat white`. When this is ordered make sure the bot does not the user what size they want.
